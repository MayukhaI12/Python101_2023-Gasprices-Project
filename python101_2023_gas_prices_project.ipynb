# %% [markdown]
# <a href="https://colab.research.google.com/github/sjasthi/python101_2023_gasprices_project/blob/main/python101_2023_gas_prices_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 101 (2022-23) Final project
# # Siva.Jasthi@metrostate.edu
# # Gas Prices
#
# Version: 5/3/2023

# %%
#@title Get the file directly using wget (web get)
# Make sure that you are using the link to the RAW file
# !wget https://raw.githubusercontent.com/sjasthi/python_input_files/main/gasprices.txt
# Out:
# --2023-05-07 15:48:43--  https://raw.githubusercontent.com/sjasthi/python_input_files/main/gasprices.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19059 (19K) [text/plain]
# Saving to: ‘gasprices.txt’
#
# gasprices.txt       100%[===================>]  18.61K  --.-KB/s    in 0s
#
# 2023-05-07 15:48:43 (84.4 MB/s) - ‘gasprices.txt’ saved [19059/19059]

# %% [markdown]
# #@title Option 1 (Design: We are storing the data as LIST of Lists) (TBD: Move it PPTX)
#
# What do we call this big list?
# - x is bad name
# - file_data - is too generic
# - prices_master_list -- we can go with this
#
# What do we call the values inside this prices_master_list?
# - y is bad name
# - line_data - is too generic
# - price_mini_list - we can go with this
#
# What do we call indiviual values within the price_mini_list?
# - month
# - date
# - year
# - price

# %%
#@title List all the global variables here
# Global variables can be accessed by every function
# prices_master_list captures all the gas prices data from the file as "list of lists"
prices_master_list = []

year_prices_dictionary = {}

month_prices_dictionary = {}

# Mentioning the variable 'about'
about = '''
Gasprices Project is implemeted in Python 101 class of 2023. 
In this project, we explored the following concepts:
-- Python Datatypes
-- Operators (Assignment, Arithmetic, and Logical)
-- Conditions and Boolean Logic
-- Functions
-- File Input/Output 
-- Lists and Tuples
-- Strings
-- Sets and Dictionaries

We met the following requirements in this project:
1. Reading the Gasprices (textfile)
2. Get Average Price per Year
3  Get Average Price per Year - Dictionary
4. Get Average Price per Month
5. Get Average Price per Month - Dictionary
6. Get Highest and Lowest Prices per Year 
7. Get Highest and Lowest Prices per Year - Dictionary
8. Generate list of Prices - Lowest to Highest  
9. Generate list of Prices - Highest to Lowest
10. Create a Price Range Coloumn 
11. Get Price Binning Frequency
12. Get Missing Dates Report
13. Runtime Summary

We used the following tools in this project:
-- Python Tutor
-- Google Colab 
-- Google Classroom
-- Zoom
-- GitHub

We implemented majority of the requirements as solo assignment/as a Mid-Term Project.
After the Mid-Term, we established a common baseline upon which we built the Final Project.
The entire classroom is divided into four groups  - Alligators, Bears, Cheetahs, and Dolphins.
We shared the remaining requirements, worked through dependencies, and used GitHub for collaboration to complete this project.
'''

# %% [markdown]
# read_gas_prices( ) requirements:
#
# read_gas_prices( ) method will now create the three data structures:
#
# FP #3. Handle the data conditions
# FP #5: Dictionary based implementation

# %%
prices_master_list = []
year_prices_dictionary = {}
month_prices_dictionary = {}

#@title read_gas_prices()  
# Reading from the file and building the prices_master_list
'''
Method Name: read_gas_prices
Input: file name
Returns: None
What global variables are updated? prices_master_list


This function takes in a gas prices file name and creates a prices_master_list
'''
def read_gas_prices(file_name = 'gasprices.txt'):
  # open the file 
  # read the line
  # split the line 
  # do any necessary data conversions 
  # build the mini list called price_mini_list
  # append this price_mini_list to the master list prices_master_list
  # return (None) out of the function
  file_contents = open(file_name, 'r')
  file_lines = file_contents.readlines()


  for s in file_lines:
    m_d_y_list = s.split('-')
    y_p_list = m_d_y_list[2].split(':')
    price = y_p_list[1].strip('\n')

    m_d_y_p_list = []
    month = int(m_d_y_list[0])
    day = int(m_d_y_list[1])
    year = int(y_p_list[0])
    price = float(price)

    m_d_y_p_list.append(month)
    m_d_y_p_list.append(day)
    m_d_y_p_list.append(year)
    m_d_y_p_list.append(price)

    #update the prices master list
    prices_master_list.append(m_d_y_p_list)

    # update the year dictionary
    # Update year_prices_dictionary
    if year not in year_prices_dictionary:
        year_prices_dictionary[year] = []
    year_prices_dictionary[year].append(price)

    # update the month dictionary
    # Update month_prices_dictionary
    if month not in month_prices_dictionary:
        month_prices_dictionary[month] = []
    month_prices_dictionary[month].append(price)


# Testing this fuction by itself
read_gas_prices()

#If the above method works correctly, then prices_master_list would have been updated with all the data from the file.
print('Number of mini lists in prices_master_list: ', len(prices_master_list))
for index in range(5):
  mini_list = prices_master_list[index]
  print(mini_list)

print('Length of Year Prices Dictionary: ', len(year_prices_dictionary))
print('Year Prices Dictionary: ', year_prices_dictionary)

print('Length of Month Prices Dictionary: ', len(month_prices_dictionary))
print('Month Prices Dictionary: ', month_prices_dictionary)
# Out:
# Number of mini lists in prices_master_list:  1065
# [4, 5, 1993, 1.068]
# [4, 12, 1993, 1.079]
# [4, 19, 1993, 1.079]
# [4, 26, 1993, 1.086]
# [5, 3, 1993, 1.086]
# Length of Year Prices Dictionary:  21
# Year Prices Dictionary:  {1993: [1.068, 1.079, 1.079, 1.086, 1.086, 1.097, 1.106, 1.106, 1.107, 1.104, 1.101, 1.095, 1.089, 1.086, 1.081, 1.075, 1.069, 1.062, 1.06, 1.059, 1.065, 1.062, 1.055, 1.051, 1.045, 1.047, 1.092, 1.09, 1.093, 1.092, 1.084, 1.075, 1.064, 1.058, 1.051, 1.036, 1.018, 1.003, 0.999], 1994: [0.992, 0.995, 1.001, 0.999, 1.005, 1.007, 1.016, 1.009, 1.004, 1.007, 1.005, 1.007, 1.012, 1.011, 1.028, 1.033, 1.037, 1.04, 1.045, 1.046, 1.05, 1.056, 1.065, 1.073, 1.079, 1.095, 1.097, 1.103, 1.109, 1.114, 1.13, 1.157, 1.161, 1.165, 1.161, 1.156, 1.15, 1.14, 1.129, 1.12, 1.114, 1.106, 1.107, 1.121, 1.123, 1.122, 1.113, 1.117, 1.127, 1.131, 1.134, 1.125], 1995: [1.127, 1.134, 1.126, 1.132, 1.131, 1.124, 1.121, 1.115, 1.121, 1.123, 1.116, 1.114, 1.121, 1.133, 1.149, 1.163, 1.184, 1.194, 1.216, 1.226, 1.244, 1.246, 1.246, 1.243, 1.236, 1.229, 1.222, 1.212, 1.2, 1.191, 1.179, 1.174, 1.172, 1.171, 1.163, 1.16, 1.158, 1.157, 1.156, 1.151, 1.144, 1.133, 1.125, 1.115, 1.112, 1.109, 1.106, 1.107, 1.108, 1.11, 1.124, 1.128], 1996: [1.129, 1.139, 1.145, 1.138, 1.133, 1.13, 1.126, 1.133, 1.153, 1.17, 1.171, 1.181, 1.21, 1.223, 1.248, 1.287, 1.301, 1.318, 1.321, 1.323, 1.33, 1.321, 1.315, 1.307, 1.302, 1.289, 1.279, 1.276, 1.273, 1.272, 1.263, 1.253, 1.248, 1.249, 1.253, 1.242, 1.247, 1.25, 1.251, 1.245, 1.239, 1.248, 1.249, 1.26, 1.268, 1.272, 1.282, 1.289, 1.287, 1.287, 1.283, 1.278, 1.274], 1997: [1.272, 1.287, 1.287, 1.284, 1.282, 1.28, 1.273, 1.27, 1.261, 1.253, 1.246, 1.25, 1.246, 1.248, 1.244, 1.245, 1.24, 1.238, 1.238, 1.247, 1.255, 1.258, 1.251, 1.242, 1.232, 1.226, 1.222, 1.219, 1.222, 1.216, 1.237, 1.272, 1.274, 1.288, 1.287, 1.288, 1.281, 1.269, 1.255, 1.254, 1.248, 1.238, 1.228, 1.221, 1.222, 1.213, 1.207, 1.197, 1.187, 1.176, 1.167, 1.158], 1998: [1.148, 1.14, 1.129, 1.112, 1.108, 1.101, 1.085, 1.09, 1.075, 1.065, 1.055, 1.047, 1.077, 1.074, 1.072, 1.075, 1.086, 1.095, 1.109, 1.109, 1.108, 1.104, 1.113, 1.104, 1.096, 1.096, 1.097, 1.092, 1.097, 1.088, 1.077, 1.072, 1.065, 1.058, 1.053, 1.046, 1.042, 1.053, 1.053, 1.059, 1.063, 1.058, 1.055, 1.05, 1.048, 1.037, 1.03, 1.015, 0.996, 0.987, 0.986, 0.979], 1999: [0.977, 0.982, 0.985, 0.977, 0.971, 0.968, 0.96, 0.949, 0.955, 0.963, 1.017, 1.056, 1.121, 1.158, 1.179, 1.175, 1.171, 1.176, 1.18, 1.18, 1.166, 1.151, 1.152, 1.148, 1.163, 1.153, 1.165, 1.182, 1.208, 1.232, 1.234, 1.246, 1.275, 1.273, 1.273, 1.282, 1.29, 1.307, 1.302, 1.296, 1.29, 1.277, 1.277, 1.271, 1.274, 1.292, 1.309, 1.315, 1.313, 1.315, 1.31, 1.314], 2000: [1.312, 1.304, 1.318, 1.354, 1.355, 1.364, 1.394, 1.443, 1.458, 1.539, 1.566, 1.569, 1.549, 1.543, 1.516, 1.486, 1.478, 1.461, 1.495, 1.531, 1.566, 1.579, 1.599, 1.664, 1.711, 1.691, 1.661, 1.63, 1.586, 1.562, 1.514, 1.504, 1.489, 1.508, 1.521, 1.568, 1.598, 1.599, 1.586, 1.563, 1.541, 1.578, 1.588, 1.584, 1.565, 1.562, 1.55, 1.549, 1.526, 1.49, 1.462, 1.453], 2001: [1.446, 1.465, 1.513, 1.511, 1.5, 1.483, 1.515, 1.489, 1.471, 1.457, 1.453, 1.444, 1.445, 1.482, 1.54, 1.61, 1.658, 1.665, 1.739, 1.748, 1.724, 1.739, 1.715, 1.688, 1.644, 1.583, 1.52, 1.484, 1.459, 1.44, 1.428, 1.419, 1.434, 1.467, 1.523, 1.579, 1.562, 1.564, 1.522, 1.455, 1.393, 1.351, 1.307, 1.277, 1.249, 1.224, 1.208, 1.168, 1.149, 1.136, 1.101, 1.113, 1.137], 2002: [1.152, 1.152, 1.146, 1.142, 1.157, 1.148, 1.157, 1.157, 1.185, 1.262, 1.328, 1.382, 1.412, 1.454, 1.446, 1.446, 1.435, 1.437, 1.431, 1.439, 1.429, 1.433, 1.417, 1.419, 1.425, 1.433, 1.423, 1.435, 1.451, 1.447, 1.437, 1.435, 1.434, 1.444, 1.436, 1.437, 1.442, 1.436, 1.455, 1.48, 1.481, 1.499, 1.485, 1.489, 1.48, 1.451, 1.423, 1.408, 1.404, 1.407, 1.443, 1.484], 2003: [1.487, 1.496, 1.502, 1.515, 1.569, 1.649, 1.701, 1.699, 1.726, 1.752, 1.768, 1.732, 1.692, 1.673, 1.639, 1.618, 1.6, 1.556, 1.534, 1.539, 1.528, 1.514, 1.53, 1.558, 1.537, 1.528, 1.53, 1.563, 1.566, 1.558, 1.576, 1.611, 1.668, 1.787, 1.786, 1.758, 1.739, 1.686, 1.635, 1.617, 1.611, 1.612, 1.584, 1.577, 1.547, 1.54, 1.554, 1.533, 1.519, 1.509, 1.528, 1.521], 2004: [ ...
# Length of Month Prices Dictionary:  12
# Month Prices Dictionary:  {4: [1.068, 1.079, 1.079, 1.086, 1.011, 1.028, 1.033, 1.037, 1.133, 1.149, 1.163, 1.184, 1.223, 1.248, 1.287, 1.301, 1.318, 1.248, 1.244, 1.245, 1.24, 1.074, 1.072, 1.075, 1.086, 1.158, 1.179, 1.175, 1.171, 1.543, 1.516, 1.486, 1.478, 1.482, 1.54, 1.61, 1.658, 1.665, 1.412, 1.454, 1.446, 1.446, 1.435, 1.673, 1.639, 1.618, 1.6, 1.822, 1.827, 1.853, 1.853, 2.258, 2.321, 2.28, 2.279, 2.631, 2.727, 2.828, 2.96, 2.753, 2.848, 2.922, 2.917, 3.017, 3.381, 3.438, 3.557, 3.653, 2.09, 2.104, 2.112, 2.102, 2.877, 2.909, 2.911, 2.901, 3.737, 3.843, 3.896, 3.932, 3.996, 3.997, 3.98, 3.929, 3.889, 3.714, 3.676, 3.611, 3.603, 3.587], 5: [1.086, 1.097, 1.106, 1.106, 1.107, 1.04, 1.045, 1.046, 1.05, 1.056, 1.194, 1.216, 1.226, 1.244, 1.246, 1.321, 1.323, 1.33, 1.321, 1.238, 1.238, 1.247, 1.255, 1.095, 1.109, 1.109, 1.108, 1.176, 1.18, 1.18, 1.166, 1.151, 1.461, 1.495, 1.531, 1.566, 1.579, 1.739, 1.748, 1.724, 1.739, 1.437, 1.431, 1.439, 1.429, 1.556, 1.534, 1.539, 1.528, 1.884, 1.979, 2.055, 2.104, 2.092, 2.277, 2.231, 2.206, 2.169, 2.141, 2.966, 2.955, 2.992, 2.938, 2.913, 3.097, 3.143, 3.258, 3.25, 3.663, 3.771, 3.84, 3.986, 2.129, 2.29, 2.36, 2.485, 2.95, 2.958, 2.918, 2.842, 2.784, 4.014, 4.018, 4.014, 3.904, 3.848, 3.849, 3.814, 3.773, 3.728, 3.602, 3.665, 3.729, 3.704], 6: [1.104, 1.101, 1.095, 1.089, 1.065, 1.073, 1.079, 1.095, 1.246, 1.243, 1.236, 1.229, 1.315, 1.307, 1.302, 1.289, 1.258, 1.251, 1.242, 1.232, 1.226, 1.104, 1.113, 1.104, 1.096, 1.096, 1.152, 1.148, 1.163, 1.153, 1.599, 1.664, 1.711, 1.691, 1.715, 1.688, 1.644, 1.583, 1.433, 1.417, 1.419, 1.425, 1.514, 1.53, 1.558, 1.537, 1.528, 2.075, 2.029, 1.981, 1.965, 2.159, 2.173, 2.204, 2.257, 2.937, 2.951, 2.917, 2.914, 3.2, 3.122, 3.057, 3.029, 4.026, 4.09, 4.134, 4.131, 4.146, 2.572, 2.673, 2.722, 2.743, 2.695, 2.78, 2.756, 2.795, 2.809, 3.833, 3.767, 3.708, 3.631, 3.671, 3.629, 3.589, 3.494, 3.705, 3.715, 3.689, 3.645], 7: [1.086, 1.081, 1.075, 1.069, 1.097, 1.103, 1.109, 1.114, 1.222, 1.212, 1.2, 1.191, 1.179, 1.279, 1.276, 1.273, 1.272, 1.263, 1.222, 1.219, 1.222, 1.216, 1.097, 1.092, 1.097, 1.088, 1.165, 1.182, 1.208, 1.232, 1.661, 1.63, 1.586, 1.562, 1.514, 1.52, 1.484, 1.459, 1.44, 1.428, 1.433, 1.423, 1.435, 1.451, 1.447, 1.53, 1.563, 1.566, 1.558, 1.939, 1.959, 1.971, 1.948, 2.268, 2.369, 2.36, 2.333, 2.979, 3.017, 3.033, 3.048, 3.05, 3.005, 3.026, 3.092, 3.005, 2.926, 4.165, 4.164, 4.118, 4.01, 2.666, 2.584, 2.519, 2.557, 2.779, 2.771, 2.775, 2.801, 3.634, 3.695, 3.736, 3.754, 3.415, 3.469, 3.485, 3.554, 3.568, 3.567, 3.563, 3.706, 3.751, 3.716], 8: [1.062, 1.06, 1.059, 1.065, 1.062, 1.13, 1.157, 1.161, 1.165, 1.161, 1.174, 1.172, 1.171, 1.163, 1.253, 1.248, 1.249, 1.253, 1.237, 1.272, 1.274, 1.288, 1.077, 1.072, 1.065, 1.058, 1.053, 1.234, 1.246, 1.275, 1.273, 1.273, 1.504, 1.489, 1.508, 1.521, 1.419, 1.434, 1.467, 1.523, 1.437, 1.435, 1.434, 1.444, 1.576, 1.611, 1.668, 1.787, 1.93, 1.92, 1.917, 1.926, 1.909, 2.335, 2.41, 2.592, 2.654, 2.653, 3.083, 3.047, 2.971, 2.893, 2.888, 2.821, 2.832, 2.796, 3.935, 3.864, 3.794, 3.738, 2.61, 2.7, 2.691, 2.682, 2.667, 2.788, 2.835, 2.798, 2.759, 2.736, 3.766, 3.73, 3.662, 3.638, 3.682, 3.702, 3.779, 3.803, 3.837, 3.701, 3.633, 3.622, 3.623], 9: [1.055, 1.051, 1.045, 1.047, 1.156, 1.15, 1.14, 1.129, 1.16, 1.158, 1.157, 1.156, 1.242, 1.247, 1.25, 1.251, 1.245, 1.287, 1.288, 1.281, 1.269, 1.255, 1.046, 1.042, 1.053, 1.053, 1.282, 1.29, 1.307, 1.302, 1.568, 1.598, 1.599, 1.586, 1.579, 1.562, 1.564, 1.522, 1.436, 1.437, 1.442, 1.436, 1.455, 1.786, 1.758, 1.739, 1.686, 1.635, 1.893, 1.889, 1.908, 1.959, 3.117, 3.002, 2.835, 2.851, 2.777, 2.67, 2.549, 2.429, 2.84, 2.862, 2.835, 2.86, 3.733, 3.701, 3.887, 3.772, 3.687, 2.642, 2.632, 2.607, 2.554, 2.735, 2.772, 2.775, 2.747, 3.727, 3.715, 3.657, 3.568, 3.903, 3.907, 3.939, 3.889], 10: [1.092, 1.09, 1.093, 1.092, 1.12, 1.114, 1.106, 1.107, 1.121, 1.151, 1.144, 1.133, 1.125, 1.115, 1.239, 1.248, 1.249, 1.26, 1.254, 1.248, 1.238, 1.228, 1.059, 1.063, 1.058, 1.055, 1 ...

# %%
#@title  get_average_price_per_year()
#Processing the prices_master_list and printing the output
'''
Method Name: get_average_price_per_year
Input: None (it relies on the global variable prices_master_list)
Returns: None
What global variables are updated? None
Displays:

Year      Average Price
1993     1.07
1994     1.09

2013     3.45
'''

def get_average_price_per_year():
    # set up a for loop for years
    # for year in range(1993, 2014):
    # you need to read the prices_master_list from beginning to end
    # if the year matches the current year, add the current price to the total
    # and print the year and average

    # print the header
    print('year\tAverage Price')
    for year in range(1993, 2014):
      counter = 0
      total_price = 0
      for list_year in prices_master_list: 
        year_elem = list_year[2]
        if year_elem == year:
          price_elem = list_year[3]
          counter += 1
          total_price = total_price + price_elem 
          average_price = total_price / counter
          formatted_float = "{:.3f}".format(average_price)
      print(year, '\t\t', formatted_float)


# Testing of this function by itself
get_average_price_per_year()
# Out:
# year	Average Price
# 1993 		 1.071
# 1994 		 1.078
# 1995 		 1.158
# 1996 		 1.245
# 1997 		 1.244
# 1998 		 1.072
# 1999 		 1.176
# 2000 		 1.523
# 2001 		 1.460
# 2002 		 1.386
# 2003 		 1.603
# 2004 		 1.895
# 2005 		 2.314
# 2006 		 2.618
# 2007 		 2.843
# 2008 		 3.299
# 2009 		 2.406
# 2010 		 2.835
# 2011 		 3.576
# 2012 		 3.680
# 2013 		 3.651

# %% [markdown]
# get_average_prices_per_year_dictionary( ):
# TO BE DONE

# %%
#@title get_average_prices_per_year_dictionary( )
def get_average_prices_per_year_dictionary( ):
  yearly_average={}
  for year,price_list in year_prices_dictionary.items():
    average = sum(price_list)/len(price_list)
    yearly_average[year]= average
  return yearly_average

x = get_average_prices_per_year_dictionary()

for year, average_price in x.items():
  print(year,average_price)
# Out:
# 1993 1.0711538461538466
# 1994 1.0778653846153845
# 1995 1.1577115384615386
# 1996 1.2445283018867925
# 1997 1.2442499999999999
# 1998 1.071711538461538
# 1999 1.1760576923076924
# 2000 1.522730769230769
# 2001 1.4603018867924529
# 2002 1.385961538461538
# 2003 1.603019230769231
# 2004 1.8946923076923083
# 2005 2.314461538461538
# 2006 2.6182692307692315
# 2007 2.8434716981132078
# 2008 3.2989038461538462
# 2009 2.4058269230769236
# 2010 2.835057692307693
# 2011 3.576423076923077
# 2012 3.6796415094339627
# 2013 3.651441176470588

# %%
#@title get_average_price_per_month()
#Processing the prices_master_list and printing the output
'''
Method Name: get_average_price_per_month()
Input: None (it relies on the global variable prices_master_list)
Returns: None
What global variables are updated? None
Displays:  average price per month in this format. 
           This output will have just 12 entries 
          (we don't care about the year) (we just have to worry about the month)

Month   Average Price
Jan     1.07
Feb     1.09
...
...
Dec     1.89
'''
def get_average_price_per_month():
  price_total = 0
  count = 0
  for m in range(1, 13):
    for data in prices_master_list:
      month = data[0]
      price = data[3]
      if m == month:
        price_total += price
        count += 1
    avg_price_per_month = price_total / count
    print(m, avg_price_per_month)



# Testing of this function by itself
get_average_price_per_month()

# Bug 1:  The names 1 to 12 are not user friendly from end user point of view
#         We want to display the Month names in "Jan", "Feb".. "Dec" format

# Bug 2 : The average price needs to be rounded off to a.bc (2 digts after the decimal)
# Out:
# 1 1.8996666666666664
# 2 1.9232705882352943
# 3 1.9622209302325573
# 4 2.0024971264367806
# 5 2.031773755656108
# 6 2.052775894538607
# 7 2.0668349358974365
# 8 2.075001394700141
# 9 2.074043640897756
# 10 2.0694983164983176
# 11 2.0559222108495407
# 12 2.0399230046948365

# %% [markdown]
# get_average_prices_per_month_dictionary( ):
# TO BE DONE

# %%
#@title get_average_prices_per_month_dictionary( )

def get_average_prices_per_month_dictionary():

# -- Creating a new dictionary -- #
  monthly_average = {}

# -- Calculating the average for each month -- #
  for key, values in month_prices_dictionary.items():
    monthly_average[key] = round((sum(values) / len(values)), 2)

# -- Printing the results -- #
  print("Month - Average Price")
  for key, average in monthly_average.items():
    if (key == 4):
      print("April", ":", average)
    elif (key == 5):
      print("May", ":", average)
    elif (key == 6):
      print("June", ":", average)
    elif (key == 7):
      print("July", ":", average)
    elif (key == 8):
      print("August", ":", average)
    elif (key == 9):
      print("September", ":", average)
    elif (key == 10):
      print("October", ":", average)
    elif (key == 11):
      print("November", ":", average)
    elif (key == 12):
      print("December", ":", average)
    elif (key == 1):
      print("January", ":", average)
    elif (key == 2):
      print("February", ":", average)
    else:
      print("March", ":", average)
    
######################################
# ------ Calling the function ------ #
get_average_prices_per_month_dictionary()
# Out:
# Month - Average Price
# April : 2.12
# May : 2.14
# June : 2.16
# July : 2.15
# August : 2.13
# September : 2.07
# October : 2.03
# November : 1.92
# December : 1.86
# January : 1.9
# February : 1.95
# March : 2.04

# %%
#@title get_highest_and_lowest_prices_per_year()
#Processing the prices_master_list and printing the output
'''
Method Name: get_highest_and_lowest_prices_per_year()
Input: None (it relies on the global variable prices_master_list)
Returns: None
What global variables are updated? None
Displays:

Year          Highest_Price          Lowest_Price
1993            1.98                  1.07
1994            1.89                  1.16
...
...
2013            3.45                  2.39
'''

def get_highest_and_lowest_prices_per_year():
  print("Year Highest Lowest")
  for y in range(1993, 2014):
    lowest_price = 100
    highest_price = 0
    for data in prices_master_list:
      year = data[2]
      if y == year:
        if data[3] < lowest_price:
          lowest_price = data[3]
        else:
          if data[3] > highest_price:
            highest_price = data[3]
    print(y, highest_price, lowest_price)



# Testing of this function by itself
get_highest_and_lowest_prices_per_year()

#Bug 3: The output could use escape strings /t (tabbed separation)
# Out:
# Year Highest Lowest
# 1993 1.107 0.999
# 1994 1.165 0.992
# 1995 1.246 1.106
# 1996 1.33 1.126
# 1997 1.288 1.158
# 1998 1.113 0.979
# 1999 1.315 0.949
# 2000 1.711 1.304
# 2001 1.748 1.101
# 2002 1.499 1.142
# 2003 1.787 1.487
# 2004 2.104 1.552
# 2005 3.117 1.824
# 2006 3.083 2.246
# 2007 3.258 2.213
# 2008 4.165 1.67
# 2009 2.746 1.737
# 2010 3.106 2.664
# 2011 4.018 3.124
# 2012 3.997 3.324
# 2013 3.851 3.373

# %% [markdown]
# get_highest_and_lowest_prices_per_year_dictionary():
# TO BE DONE

# %%
#@title get_highest_and_lowest_prices_per_year_dictionary()

def get_highest_and_lowest_prices_per_year_dictionary():
  print('Year\t\tHighest Price\t\tLowest Price')

  #for year in range(1993, 2014):
  for key_elem in year_prices_dictionary.keys():
    year = key_elem

    # print(year)  
    price_elem = year_prices_dictionary.get(year)
    # print(price_elem)
    
    highest_price = max(price_elem)
    # print(highest_price)

    lowest_price = min(price_elem)
    # print(lowest_price)

    print(year, '\t\t', highest_price, '\t\t\t', lowest_price)

get_highest_and_lowest_prices_per_year_dictionary()
# Out:
# Year		Highest Price		Lowest Price
# 1993 		 1.107 			 0.999
# 1994 		 1.165 			 0.992
# 1995 		 1.246 			 1.106
# 1996 		 1.33 			 1.126
# 1997 		 1.288 			 1.158
# 1998 		 1.148 			 0.979
# 1999 		 1.315 			 0.949
# 2000 		 1.711 			 1.304
# 2001 		 1.748 			 1.101
# 2002 		 1.499 			 1.142
# 2003 		 1.787 			 1.487
# 2004 		 2.104 			 1.552
# 2005 		 3.117 			 1.824
# 2006 		 3.083 			 2.246
# 2007 		 3.258 			 2.213
# 2008 		 4.165 			 1.67
# 2009 		 2.746 			 1.737
# 2010 		 3.106 			 2.664
# 2011 		 4.018 			 3.124
# 2012 		 3.997 			 3.324
# 2013 		 3.851 			 3.373

# %%
#@title generate_list_of_prices_lowest_to_highest()
#Processing the prices_master_list and writing the output to 'gasprices_low_to_high.txt'
'''
This method generates a text file that lists the dates and prices, 
sorted from the lowest price to the highest

Since the file name is not given, we can call the output file as 'gasprices_low_to_high.txt'

02.22.1999:0.949
03.01.1999:0.955


'''

# take the fourth element for sort
def take_price(elem):
    return elem[3]

def generate_list_of_prices_lowest_to_highest():
  file_name = 'gas_prices_lowest_to_highest.txt'
  file_object = open(file_name, 'w')
  # sort list with key
  sorted_list = sorted(prices_master_list, key=take_price)
  for x in sorted_list:
    m = x[0]
    d = x[1]
    y = x[2]
    p = x[3]
    formatted_string = str(m) + '-' + str(d) + '-' + str(y) +':' + str(p) + '\n'
    file_object.write(formatted_string)
  
  #close the file
  file_object.close()

# Testing of this function by itself
generate_list_of_prices_lowest_to_highest()

# %%
#@title generate_list_of_prices_highest_to_lowest()
#Processing the prices_master_list and writing the output to 'gasprices_high_to_low.txt'
'''
This method generates a text file that lists the dates and prices, 
sorted from the highest price to the lowest.

Since the file name is not given, we can call the output file as 'gasprices_high_to_low.txt'

01.29.203:4.56



03.01.1999:0.955
02.22.1999:0.949
'''

def generate_list_of_prices_highest_to_lowest():
  file_name = 'gas_prices_highest_to_lowest.txt'
  file_object = open(file_name, 'w')
  # sort list with key
  sorted_list = sorted(prices_master_list, key=take_price, reverse=True)
  for x in sorted_list:
    m = x[0]
    d = x[1]
    y = x[2]
    p = x[3]
    formatted_string = str(m) + '-' + str(d) + '-' + str(y) +':' + str(p) + '\n'
    file_object.write(formatted_string)
  
  #close the file
  file_object.close()

# Testing of this function by itself
generate_list_of_prices_highest_to_lowest() 

#Bug 4: Give some visual indication (print to say "the file is created")

# %% [markdown]
# FP #1. Price Binning
# create_price_range_column()

# %%
#@title create_price_range_column()
''' create a text file called "gas_prices_bin_data' with an additional column 
mentioning the bin name for each line item 

date:price:bin_name
'''

range1 = 0.949
range2 = 1.753
range3 = 2.557
range4 = 3.364
range5 = 4.165

def get_bin_name(input_price):
  bin_name = ' '
  
  if input_price >= range1 and input_price < range2:
    bin_name='Low'
  if input_price >= range2 and input_price < range3:
    bin_name='Medium'
  if input_price >= range3 and input_price < range4:
    bin_name='High'
  if input_price >= range4 and input_price < range5:
    bin_name='Very High'

  return bin_name

def create_price_range_column():
  with open("/gasprices.txt",'r') as data_file:
    with open('/gas_prices_binning.txt','w') as new_file:
      for line in data_file:
        gasList = line.split(':')
        date = gasList[0]
        price_str = gasList[1]
        price_str = price_str[:-1]
        price_float = float(price_str)
        pricerange = get_bin_name(price_float)
        new_file.write(date+':'+price_str+':'+pricerange+'\n')

# %%
#@title get_price_binning_frequency( )

# !git clone https://github.com/samhita13/Python101/blob/main/python101_2023_gas_prices_project_(1).ipynb
def get_price_binning_frequency( ):
  binfreqdictionary = { 
      "Low" : 0,
      "Medium" : 0,
      "High" : 0,
      "Very High" : 0
  }
  
  with open("gas_prices_binning.txt") as file:
    for each_line in file:
      linelist=each_line.split(":")
      linelist[2].replace('\n','')
      binfreqdictionary[linelist[2]] = binfreqdictionary[linelist[2]] + 1
      #binfreqdictionary['Low'] = binfreqdictionay['Low'] + 1

  print(binfreqdictionary)
  pass
get_price_binning_frequency()

# %%
#@ Get Missing Dates Report
def get_missing_dates_report():
    import datetime

    # Read the gas prices from the file
    with open("gasprices.txt") as f:
        gas_prices = f.readlines()

    # Extract the dates from the gas prices
    dates = [datetime.datetime.strptime(gp.split(":")[0], "%m-%d-%Y").date() for gp in gas_prices]

    # Find the missing dates
    start_date = dates[0]
    end_date = dates[-1]
    all_dates = set([start_date + datetime.timedelta(days=x) for x in range((end_date - start_date).days)])
    missing_dates = sorted(list(all_dates - set(dates)))

    # Print the report
    if len(missing_dates) == 0:
        print("No missing dates found.")
    else:
        print("Missing dates:")
        for missing_date in missing_dates:
            print(missing_date.strftime("%m-%d-%Y"))
get_missing_dates_report()

# %%
#@title print_runtime_summary( )
# This code cell calls all of the above methods and prints the runtime summary to the console.

'''
Function Name												          Time Taken
def read_gas_prices() 									        	0.004
def get_average_price_per_year()							    0.008
def get_average_price_per_month()
def get_highest_and_lowest_prices_per_year()
def generate_list_of_prices_lowest_to_highest()
def generate_list_of_prices_highest_to_lowest()
									            Total Time					4.000

'''
def print_runtime_summary():
			import time
			import random


			# An example of how to capture the run time
			'''
			start_time = time.time() 
			print(start_time)

			for x in range(100000000):
				y = random.randint(1, 100)
			
			end_time = time.time() 
			print(start_time) 

			run_time = end_time - start_time

			print('Execution time for generating 100000000 random numbers: ', run_time)
			'''


			# Capturing the rutime for def read_gas_prices() 	
			start_time = time.time()  
			read_gas_prices() 	
			end_time = time.time()  
			run_time_for_read_gas_prices = end_time - start_time


			# Capturing the rutime for get_average_price_per_year
			start_time = time.time()  
			get_average_price_per_year() 	
			end_time = time.time()  
			run_time_for_get_average_price_per_year = end_time - start_time



			# Capturing the rutime for def read_gas_prices() 	
			start_time = time.time()  
			get_average_price_per_month() 	
			end_time = time.time()  
			run_time_for_get_average_price_per_month = end_time - start_time


			# Repeat the process for other three methods
			start_time = time.time()  	
			generate_list_of_prices_lowest_to_highest()
			end_time = time.time()  
			run_time_generate_list_of_prices_lowest_to_highest = end_time - start_time


			start_time = time.time()  	
			generate_list_of_prices_highest_to_lowest()
			end_time = time.time()  
			run_time_generate_list_of_prices_higest_to_lowest = end_time - start_time



			print('\n\n=================================================')
			print('read_gas_prices( ) runtime : ', run_time_for_read_gas_prices)
			print('get_average_price_per_year( ) runtime : ', run_time_for_get_average_price_per_year)
			print('get_average_price_per_month( ) runtime : ', run_time_for_get_average_price_per_month)
			print('generate_list_of_prices_lowest_to_highest( ) runtime : ', run_time_generate_list_of_prices_lowest_to_highest)
			print('generate_list_of_prices_highest_to_lowest( ) runtime : ', run_time_generate_list_of_prices_higest_to_lowest)


			#Bug x: Print the table in such a way that it is neatly formatted (and it looks like a table)
			#Bug x: The running times should be rounded off to two decimals (a.bc)

# %%
#@title Interactive Menu 

# Giving the user the menu/options that are present in our Gasprices_Project and asking him to choose one
menu = """
===========================================================

1. Reading the Gasprices (textfile)
2. Get Average Price per Year
3  Get Average Price per Year - Dictionary
4. Get Average Price per Month
5. Get Average Price per Month - Dictionary
6. Get Highest and Lowest Prices per Year 
7. Get Highest and Lowest Prices per Year - Dictionary
8. Generate list of Prices - Lowest to Highest  
9. Generate list of Prices - Highest to Lowest
10. Create a Price Range Coloumn 
11. Get Price Binning Frequency
12. Get Missing Dates Report
13. Runtime Summary
14. About 
15. Quit

===========================================================
"""

# Defining the Function
while True:
  print(menu)
  user_answer = input('Please choose one of the method numbers: ')
  print('\n')
  
  if user_answer == '1':
    read_gas_prices()  

  elif user_answer == '2':
    get_average_price_per_year()                                            

  elif user_answer == '3':
    get_average_prices_per_year_dictionary()

  elif user_answer == '4':
    get_average_price_per_month()

  elif user_answer == '5':
    get_average_prices_per_month_dictionary()

  elif user_answer == '6':
    get_highest_and_lowest_prices_per_year()

  elif user_answer == '7':
    get_highest_and_lowest_prices_per_year_dictionary()

  elif user_answer == '8':
    generate_list_of_prices_lowest_to_highest()

  elif user_answer == '9':
    generate_list_of_prices_highest_to_lowest() 

  elif user_answer == '10':
    create_price_range_column()

  elif user_answer == '11':
    get_price_binning_frequency()   

  elif user_answer == '12':
    get_missing_dates_report()

  elif user_answer == '13':
    print_runtime_summary() 

  elif user_answer == '14':
    print(about) 

  elif user_answer == '15':
    print('Thank You for using our Gasprices Project.')
    break
            
  else:
    print('Please enter a valid number between 1 to 15.')
